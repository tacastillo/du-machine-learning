# %%
import psycopg2
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
from datetime import datetime

import json
import statistics

import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter, MaxNLocator
# %matplotlib inline

# %%
with open('config.json') as file:
    config = json.load(file)
    host = config['host']
    database = config['database']
    user = config['user']
    password = config['password']

# %%
engine = create_engine(f'postgresql://{user}:{password}@{host}:5432/{database}')

# %%
query = """
SELECT enc."PtID", enc."HospID", enc."Rel_Discharge_Day", demo."Sex", demo."Race1", enc."Payer_Type"
FROM ms_encounters AS enc
INNER JOIN ms_demographicss as demo
ON enc."AdmtID"=demo."AdmtID"
where enc."EncType" = 'I'
"""

demographics = pd.read_sql_query(query, engine)

# %%
hosp_id_map = {}

for i, hosp_id in enumerate(demographics['HospID'].unique()):
    hosp_id_map[hosp_id] = i

# %%
demographics['hosp_id_enum'] = demographics.apply(lambda row: hosp_id_map[row['HospID']], axis=1)

# %%
def chunk_features(df):
    chunk_one = df[df['Rel_Discharge_Day'] <= 3].reset_index(drop=True)
    chunk_two = df[df['Rel_Discharge_Day'] > 3].reset_index(drop=True)
    
    return (chunk_one, chunk_two)

def plot_overlapping_histogram(df1, df2, col, hist_params):
    ax = df1[col].hist(**hist_params, label="0-3",  weights=[1/len(df1[col])]*len(df1[col]))
    df2[col].hist(**hist_params, label="3+", ax=ax, weights=[1/len(df2[col])]*len(df2[col]))
#     df3[col].hist(**hist_params, label="10+", ax=ax, weights=[1/len(df3[col])]*len(df3[col]))
    ax.legend()
    return ax
    
def chunk_and_plot(df, column, hist_params):
    chunk_one, chunk_two = chunk_features(df)
    ax = plot_overlapping_histogram(chunk_one, chunk_two, column, hist_params)
    return ax

def enumerate_categorical_variables(df, col, new_col_name):
    variable_map = {}
    
    for i, value in enumerate(df[col].unique()):
        variable_map[value] = i
        
    df[new_col_name] = df.apply(lambda row: variable_map[row[col]], axis=1)
    return variable_map
    
def chunk_and_plot_categorical(df, col, hist_params):
    enum_col = f"{col}_enum"
    variable_map = enumerate_categorical_variables(df, col, enum_col)
    ax = chunk_and_plot(df, enum_col, hist_params)
    ax.set_title(col)
    
    def format_fn(tick_val, tick_pos):
        variable_list = list(variable_map.keys())
        if int(tick_val) in range(len(variable_list)):
            return variable_list[int(tick_val)]
        else:
            return ''
    
    ax.xaxis.set_major_formatter(FuncFormatter(format_fn))
    ax.xaxis.set_major_locator(MaxNLocator(integer=True))
    for label in ax.get_xticklabels():
        label.set_rotation(45)
        label.set_ha('right')

# %%
chunk_and_plot_categorical(demographics, 'HospID', {
    "alpha": 0.4
})

# %%
enumerate_categorical_variables(demographics, 'Payer_Type', 'Payer_Type_enum')

# %%
chunk_and_plot_categorical(demographics, 'Payer_Type', {
    "range": (0, 8),
    "alpha": 0.4,
    "log": True
})

# %%
enumerate_categorical_variables(demographics, 'Race1', 'race_enum')

# %%
chunk_and_plot_categorical(demographics, 'Race1', {
    "alpha": 0.5,
    "log": True
})

# %%
query = """
select  me."Rel_Discharge_Day", md."OrigDX"
from ms_encounters me 
join ms_diagnosis md
on me."AdmtID" = md."AdmtID" 
where me."EncType" = 'I'
"""

dx = pd.read_sql_query(query, engine)

# %%
def mark_diagnosis(row, diagnosis):
    if row['OrigDX'] == diagnosis:
        return 'Has'
    else:
        return "Hasn't"

# %%
diagnoses = ['I10', 'E78.5', 'E11.9', 'I25.10', 'J44.9', 'I12.9', 'Y83.8', 'A41.9']

for diagnosis in diagnoses:
    label = f"has_{diagnosis}"
    dx[label] = dx.apply(lambda row: mark_diagnosis(row,  diagnosis), axis=1)
    chunk_and_plot_categorical(dx, label, {
        "alpha": 0.4,
        "log": True
    })
    plt.show()

# %%
query = """
select mv.*, me."Rel_Discharge_Day" from ms_vitals mv
right join ms_encounters me 
on mv."AdmtID" =me."AdmtID" 
where "Vital_Rel_Day" >=0
and me."EncType" = 'I'
"""

vitals_at_admission = pd.read_sql_query(query, engine)

query = """
SELECT * FROM ms_encounters WHERE "EncType"='I'
"""

inpatient_encounters = pd.read_sql_query(query, engine)

def convert_to_datetime(row):
    return datetime.strptime('23:59:59', '%H:%M:%S') if row['Vital_Rpt_Time'] == '?' else datetime.strptime(row['Vital_Rpt_Time'], '%H:%M:%S')

vitals_at_admission['Vital_datetime'] = vitals_at_admission.apply(lambda row: convert_to_datetime(row), axis=1)

vitals_at_admission.sort_values(['Vital_Rel_Day', 'Vital_datetime'], inplace=True)

inpatient_admission_ids = inpatient_encounters['AdmtID']
vitals_for_inpatient_stays = vitals_at_admission[vitals_at_admission['AdmtID'].isin(inpatient_admission_ids)]
groupby_admissions = vitals_for_inpatient_stays.groupby('AdmtID')

# %%
vitals_dict = {}

def get_mean_of_continuous_variable(df, code, num_recent = 3):
    matched_code = df[df['Source_System_Original_Code'] == code]
    n_most_recent = matched_code.tail(num_recent)
    mean = n_most_recent['Vital_Result_Value_Txt'].astype(float).mean()
    return mean

def split_blood_pressure(blood_pressures):
    systolics = []
    diastolics = []
    for blood_pressure in blood_pressures:
        if blood_pressure is None:
            continue
        split = blood_pressure.split('/')
        systolics.append(int(split[0]))
        diastolics.append(int(split[1]))
    return (systolics, diastolics)

for name, group in groupby_admissions:
    blood_pressures = group[group['Vital_Id_Txt'] == 'Blood pressure:']['Vital_Result_Value_Txt'].reset_index(drop=True)

    systolic, diastolic = split_blood_pressure(blood_pressures)
    
    temperature_c = group[group['Source_System_Original_Code'] == 'K33010002A']['Vital_Result_Value_Txt'].reset_index(drop=True).astype(float)
    temperature_f = group[group['Source_System_Original_Code'] == 'K33010003A']['Vital_Result_Value_Txt'].reset_index(drop=True).astype(float)
    temperature_f_to_c = temperature_f.apply(lambda f: (f - 32) * (5/9))
    temperature_c.append(temperature_f_to_c)
    
    weight_kg = group[group['Source_System_Original_Code'] == 'K31010003A']['Vital_Result_Value_Txt'].reset_index(drop=True).astype(float)
    weight_lb = group[group['Source_System_Original_Code'] == 'K31010001A']['Vital_Result_Value_Txt'].reset_index(drop=True).astype(float)
    weight_lb_to_kg = weight_lb.apply(lambda lb: lb / 2.205)
    weight_kg.append(weight_lb_to_kg)
    
    
    vitals_dict[name] = {
        "mean_pulse": get_mean_of_continuous_variable(group, 'K33010006A'),
        "mean_oxygen_levels": get_mean_of_continuous_variable(group, 'L35010001A'),
        "mean_temperature_c": temperature_c.mean(),
        "mean_weight_kg": weight_kg.mean(),
        "systolic_blood_pressure": -1 if len(systolic) == 0 else statistics.mean(systolic[-3:]),
        "diastolic_blood_pressure": -1 if len(diastolic) == 0 else statistics.mean(diastolic[-3:]),
        "Rel_Discharge_Day": group['Rel_Discharge_Day'].reset_index(drop=True)[0]
    }

# %%
aggregated_vitals = pd.DataFrame(vitals_dict).T.reset_index().rename(index=int, columns={'index': 'AdmtID'})
aggregated_vitals.fillna(-1, inplace=True)

# %%
vitals_at_admission
# Out:
#                AdmtID  mean_pulse  mean_oxygen_levels  mean_temperature_c  \
# 0  172480817323018509   68.000000           96.000000           36.421739
# 1  181550818221412364  110.333333           96.666667           36.725000
# 2  181799000166943661   84.000000           93.000000           36.566667
# 3  181799000203983706   61.000000           94.666667           36.420000
# 4  181799000215963959   -1.000000           -1.000000           36.000000
#
#    mean_weight_kg  systolic_blood_pressure  diastolic_blood_pressure  \
# 0           -1.00               116.333333                 66.333333
# 1           29.30               105.000000                 63.333333
# 2           96.25               136.333333                 83.000000
# 3           -1.00                96.666667                 65.000000
# 4           -1.00                -1.000000                 -1.000000
#
#    Rel_Discharge_Day
# 0              104.0
# 1               51.0
# 2               27.0
# 3              134.0
# 4                5.0

# %%
chunk_and_plot(aggregated_vitals, 'mean_pulse', {
    "bins": 50,
    "range": (25, 175),
    "alpha": 0.4
})
plt.show()
chunk_and_plot(aggregated_vitals, 'mean_pulse', {
    "bins": 50,
    "log": True,
    "range": (25, 175),
    "alpha": 0.4
})

# %%
chunk_and_plot(aggregated_vitals, 'mean_oxygen_levels', {
    "bins": 50,
    "range": (40, 100),
    "alpha": 0.5,
})
plt.show()
chunk_and_plot(aggregated_vitals, 'mean_oxygen_levels', {
    "bins": 50,
    "range": (40, 100),
    "alpha": 0.5,
    "log": True
})

# %%
chunk_and_plot(aggregated_vitals, 'mean_temperature_c', {
    "bins": 50,
    "range": (36, 38),
    "alpha": 0.4,
})
plt.show()
chunk_and_plot(aggregated_vitals, 'mean_temperature_c', {
    "bins": 50,
    "range": (34, 40),
    "alpha": 0.4,
    "log": True
})

# %%
chunk_and_plot(aggregated_vitals, 'mean_weight_kg', {
    "bins": 50,
    "range": (0, 200),
    "alpha": 0.4,
})
plt.show()
chunk_and_plot(aggregated_vitals, 'mean_weight_kg', {
    "bins": 50,
    "range": (0, 200),
    "alpha": 0.4,
    "log": True
})

# %%
chunk_and_plot(aggregated_vitals, 'systolic_blood_pressure', {
    "bins": 50,
    "alpha": 0.5,
    "range":(75,175)
})
plt.show()
chunk_and_plot(aggregated_vitals, 'systolic_blood_pressure', {
    "bins": 50,
    "alpha": 0.5,
    "range":(75,175),
    "log": True
})

# %%
chunk_and_plot(aggregated_vitals, 'diastolic_blood_pressure', {
    "bins": 50,
    "alpha": 0.4,
    "range": (20, 120)
})
plt.show()
chunk_and_plot(aggregated_vitals, 'diastolic_blood_pressure', {
    "bins": 50,
    "alpha": 0.4,
    "range": (20, 120),
    "log": True
})

# %%
def mark_procedure(row, procedure):
    if row['PX_Desc'] == procedure:
        return 'Received'
    else:
        return "Hasn't Received"

px_features = [
    "COMPLETE CBC AUTOMATED",
    "Fentanyl citrate injection",
    "TISSUE EXAM BY PATHOLOGIST",
    "Morphine sulfate injection",
    "Catheter, guiding",
    "TX/PRO/DX INJ NEW DRUG ADDON"
]

# %%
query = """
select mp."PX_Desc", me."Rel_Discharge_Day"
from ms_procedures mp 
inner join ms_encounters me 
on mp."AdmtID" = me."AdmtID" 
where mp."Rel_Service_Day" <= 0
"""

procedures = pd.read_sql_query(query, engine)
px_df = procedures[["Rel_Discharge_Day"]]

# %%
for px, i in procedures["PX_Desc"].value_counts()[:25].iteritems():
    label = f"received_{px}"
    px_df[label] = procedures.apply(lambda row: mark_procedure(row,  px), axis=1)
    print(px)
    chunk_and_plot_categorical(px_df, label, {
        "alpha": 0.4,
        "log": True
    })
    plt.show()
# Out:
# Ondansetron hcl injection
# Inj, propofol, 10 mg
# Ringers lactate infusion
# COMPLETE CBC AUTOMATED
# Normal saline solution infus
# Compounded drug, noc
# Dexamethasone sodium phos
# Inj midazolam hydrochloride
# Cefazolin sodium injection
# Anchor/screw bn/bn,tis/bn
# TISSUE EXAM BY PATHOLOGIST
# METABOLIC PANEL TOTAL CA
# Joint device (implantable)
# ELECTROCARDIOGRAM TRACING
# Ketorolac tromethamine inj
# COMPREHEN METABOLIC PANEL
# BLOOD TYPING SEROLOGIC RH(D)
# BLOOD TYPING SEROLOGIC ABO
# RBC ANTIBODY SCREEN
# PROTHROMBIN TIME
# Inj heparin sodium per 1000u
# Guide wire
# Fentanyl citrate injection
# Neostigmine methylslfte inj
# EMERGENCY DEPT VISIT

# %%
interesting_procedures = [
    "Ondansetron hcl injection",
    "Anchor/screw bn/bn,tis/bn",
    "Joint device (implantable)",
    "COMPREHEN METABOLIC PANEL",
    "Ketorolac tromethamine inj"
]

# %%
query = """
select *, me."Rel_Discharge_Day" 
from ms_inpatient_pharm mip 
inner join ms_encounters me 
on mip."AdmtID" = me."AdmtID" 
where mip."Rel_Admin_Date" <= 0
"""

meds = pd.read_sql_query(query, engine)

# %%
top_25_meds = meds["Med"].value_counts()[:25]

# %%
def mark_med(row, med):
    if row['Med'] == med:
        return 'Received'
    else:
        return "Hasn't Received"
    
meds_df = meds[["Rel_Discharge_Day"]]
meds_df = meds_df.loc[:,~meds_df.columns.duplicated()]

for med, i in top_25_meds.iteritems():
    label = f"received_{med}"
    meds_df[label] = meds.apply(lambda row: mark_med(row,  med), axis=1)
    print (med)
    chunk_and_plot_categorical(meds_df, label, {
        "alpha": 0.4,
        "log": True
    })
    plt.show()
# Out:
# DILAUDID
# SUBLIMAZE
# ZOFRAN
# ?
# VERSED
# LACTATED RINGERS
# ROXICODONE
# TylenoL
# NACL-0.9%
# FENTANYL
# DILAUDID (iSECURE SYRINGE)
# PEPCID
# TORADOL
# KEFZOL / ANCEF
# CeleBREX
# SODIUM CHLORIDE 0.9%
# NEURONTIN
# TYLENOL EXTRA STRENGTH
# fentaNYL CITRATE
# MORPHINE
# 0.9 % SODIUM CHLORIDE
# ULTRAM
# HEPARIN
# ANCEF
# COLACE

# %%
interesting_medications = [
    "SUBLIMAZE",
    "VERSED",
    "SODIUM CHLORIDE 0.9%",
    "0.9 % SODIUM CHLORIDE"
]

# %%
query = """
SELECT * FROM ms_encounters WHERE "EncType"='I'
"""

inpatient_encounters = pd.read_sql_query(query, engine)

# %%
inpatient_encounters.head()
# Out:
#    index  HospID       PtID              AdmtID  Admit_Year  \
# 0      1   27400  137172158  190599000401972101        2019
# 1      4   27300  137094979  190459000158965684        2019
# 2      6   27450  226440736  190469000186984828        2019
# 3      7   27400  136514109  190089000208952415        2019
# 4      8   27100  138268613  190499000159892880        2019
#
#    Rel_Discharge_Day                               Reason_For_Visit_Txt  \
# 0                  7                           WOUND INFECTION LEFT LEG
# 1                  2                                     DEVERTICULITIS
# 2                  5                                       PNEUMOTHORAX
# 3                  3                                       THROMBECTOMY
# 4                 43  18% TBSA BURNS TO RT THIGH,LOWERGROIN,LTFOOT,BUTT
#
#   Pat_ZIP_Masked EncType    DRG DRG_Type HCA_Adm_Src HCA_Adm_Class  \
# 0            800       I  478         10         1               A
# 1            802       I  331         10         1               A
# 2            802       I  243         10         1               A
# 3            800       I  253         10         1               A
# 4            800       I  928         10         1               A
#
#    HCA_Disch_Dispo                               HCA_Disch_Dispo_Desc  \
# 0                6  Discharged/transferred to Home Under Care of O...
# 1                1  Discharged to Home or Self Care (Routine Disch...
# 2                1  Discharged to Home or Self Care (Routine Disch...
# 3                1  Discharged to Home or Self Care (Routine Disch...
# 4               62  Discharged/transferred to an Inpatient Rehabil...
#
#    Age_Years             Payer_Type
# 0         60        BLUE CROSS/COST
# 1         69  MANAGED CARE MEDICARE
# 2        999         MEDICARE - PPS
# 3         64                    PPO
# 4         50         MEDICARE - PPS

# %%
hist_params = {
    "bins": 15,
    "range": (0,15)
}

inpatient_encounters['Rel_Discharge_Day'].hist(**hist_params)

# %%
inpatient_encounters['Rel_Discharge_Day'].median()
# Out:
# 3.0

# %%
vitals_at_admission[vitals_at_admission['Rel_Discharge_Day'] < 3]
# Out:
#            index  HospID       PtID              AdmtID Vital_Rpt_Time  \
# 3094       11130   27150  135849845  183409000212939759       00:00:00
# 3682       12570   27150  135849845  183409000212939759       00:00:00
# 4451       14302   27200  137041712  190089000137044908       00:00:00
# 4775       15022   27200  137041712  190089000137044908       00:00:00
# 5100       15742   27200  137041712  190089000137044908       00:00:00
# ...          ...     ...        ...                 ...            ...
# 3886083  4437355   27300  137088745  183379000175992482       05:32:00
# 3886249  4437530   27300  137088745  183379000175992482       05:32:00
# 3886415  4437705   27300  137088745  183379000175992482       05:32:00
# 3886579  4437880   27300  137088745  183379000175992482       05:32:00
# 3886743  4438055   27300  137088745  183379000175992482       05:32:00
#
#                    Vital_Id_Txt           Vital_Result_Value_Txt Vital_UOM  \
# 3094                     Pulse:                               75         ?
# 3682                     Pulse:                               77         ?
# 4451             Temperature C:                             37.3  c
# 4775     Blood pressure source:  NoninvsMon:Non-invasive monitor         ?
# 5100                    SPO2 %:                               97  %
# ...                         ...                              ...       ...
# 3886083                 SPO2 %:                               94  %
# 3886249                  Pulse:                               66         ?
# 3886415       Respiratory rate:                               18         ?
# 3886579          Temperature C:                             36.6  c
# 3886743         Blood pressure:                           106/50  mmHg
#
#          Vital_Rel_Day Source_System_Original_Code  Rel_Discharge_Day  \
# 3094                 0                  K33010006A                  2
# 3682                 0                  K33010006A                  2
# 4451                 0                  K33010002A                  2
# 4775                 0                  K33010028A                  2
# 5100                 0                  L35010001A                  2
# ...                ...                         ...                ...
# 3886083             16                  L35010001A                  0
# 3886249             16                  K33010006A                  0
# 3886415             16                  K33010016A                  0
# 3886579             16                  K33010002A                  0
# 3886743             16                  K33010024A                  0
#
#              Vital_datetime
# 3094    1900-01-01 00:00:00
# 3682    1900-01-01 00:00:00
# 4451    1900-01-01 00:00:00
# 4775    1900-01-01 00:00:00
# 5100    1900-01-01 00:00:00
# ...                     ...
# 3886083 1900-01-01 05:32:00
# 3886249 1900-01-01 05:32:00
# 3886415 1900-01-01 05:32:00
# 3886579 1900-01-01 05:32:00
# 3886743 1900-01-01 05:32:00
#
# [483844 rows x 12 columns]

# %%
aggregated_vitals[aggregated_vitals['Rel_Discharge_Day'] < 3]
# Out:
#                   AdmtID  mean_pulse  mean_oxygen_levels  mean_temperature_c  \
# 0     172480817323018509   75.333333           94.666667           36.443750
# 1     181550818221412364   98.000000           95.666667           36.825000
# 2     181799000166943661   79.000000           90.666667           36.640000
# 5     181809000258911159   75.000000           95.666667           36.459259
# 9     181879000224964779   81.333333           97.333333           36.728571
# ...                  ...         ...                 ...                 ...
# 9786  193659000202951682   87.000000           92.666667           36.600000
# 9787  193659000212954133   83.000000           95.666667           37.210811
# 9789  193659000215923082   77.000000           92.000000           37.114286
# 9793  193659000240927091   91.000000           98.666667           36.812500
# 9795  193659000246920711   57.666667           99.000000           36.628571
#
#       mean_weight_kg  systolic_blood_pressure  diastolic_blood_pressure  \
# 0              -1.00                97.333333                 56.333333
# 1              29.30               108.666667                 70.333333
# 2              95.40               135.333333                 76.000000
# 5              -1.00               137.333333                 83.666667
# 9              44.50               103.333333                 66.666667
# ...              ...                      ...                       ...
# 9786           -1.00               122.000000                 66.666667
# 9787           -1.00                92.666667                 65.333333
# 9789           -1.00               119.333333                 71.333333
# 9793           61.45               118.666667                 75.333333
# 9795           -1.00               104.333333                 54.666667
#
#       Rel_Discharge_Day
# 0                   2.0
# 1                   1.0
# 2                   1.0
# 5                   2.0
# 9                   1.0
# ...                 ...
# 9786                1.0
# 9787                2.0
# 9789                2.0
# 9793                1.0
# 9795                2.0
#
# [3955 rows x 8 columns]

# %%
# mean arterial pressure

# %%
# Calculate importance
# Random forest
# the more different the histograms are, the important the feature is
# TODO:
    # Qualitatively look at different featurs and rank them yourself
        # Rank them by difference
        # For discrete vars
            # rank them from 1 to N
    # MAke a fn that calculates the difference between histograms
        # the less they overlap, the important the feature
        # go through each of the bins, use numpy
        # make sure they're normalized
        # output a number/ranking
            # see if it matches the qualitative view
    # Run a random forest with all the variables to define show what is important
    # If time:
        # Find new variables
    # Probably should just use 0-3 and 3+
        # Look into 0-3, 3-10, 10+
